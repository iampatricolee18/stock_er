# %%
#!pip install yfinance
# Out:
# ...
#      ---------------------------------------- 63.2/63.2 kB 3.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 112.2/112.2 kB 1.3 MB/s eta 0:00:00
# ...

# %%
# import library

import yfinance as yf
import pandas as pd, numpy as np

# %%
# Constants

start_date = '2020-01-01'
end_date = '2022-01-01'
 
# Add multiple space separated tickers here
ticker = 'GOOGL MSFT TSLA'

# %%
# import stock data

data = yf.download(ticker, start_date, end_date)

type(data)
# Out:
# [*********************100%***********************]  3 of 3 completed
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#             Adj Close                             Close              \
#                 GOOGL        MSFT       TSLA      GOOGL        MSFT
# Date
# 2020-01-02  68.433998  155.422043  28.684000  68.433998  160.619995
# 2020-01-03  68.075996  153.486740  29.534000  68.075996  158.619995
# 2020-01-06  69.890503  153.883514  30.102667  69.890503  159.029999
# 2020-01-07  69.755501  152.480408  31.270666  69.755501  157.580002
# 2020-01-08  70.251999  154.909180  32.809334  70.251999  160.089996
#
#                             High                               Low  \
#                  TSLA      GOOGL        MSFT       TSLA      GOOGL
# Date
# 2020-01-02  28.684000  68.433998  160.729996  28.713333  67.324501
# 2020-01-03  29.534000  68.687500  159.949997  30.266666  67.365997
# 2020-01-06  30.102667  69.916000  159.100006  30.104000  67.550003
# 2020-01-07  31.270666  70.175003  159.669998  31.441999  69.578003
# 2020-01-08  32.809334  70.592499  160.800003  33.232666  69.631500
#
# ...

# %%
data.columns
# Out:
# MultiIndex([('Adj Close', 'GOOGL'),
#             ('Adj Close',  'MSFT'),
#             ('Adj Close',  'TSLA'),
#             (    'Close', 'GOOGL'),
#             (    'Close',  'MSFT'),
#             (    'Close',  'TSLA'),
#             (     'High', 'GOOGL'),
#             (     'High',  'MSFT'),
#             (     'High',  'TSLA'),
#             (      'Low', 'GOOGL'),
#             (      'Low',  'MSFT'),
#             (      'Low',  'TSLA'),
#             (     'Open', 'GOOGL'),
#             (     'Open',  'MSFT'),
#             (     'Open',  'TSLA'),
#             (   'Volume', 'GOOGL'),
#             (   'Volume',  'MSFT'),
#             (   'Volume',  'TSLA')],
#            )

# %%
help(yf)
# Out:
# Help on package yfinance:
#
# NAME
#     yfinance
#
# DESCRIPTION
#     # -*- coding: utf-8 -*-
#     #
#     # yfinance - market data downloader
#     # https://github.com/ranaroussi/yfinance
#     #
#     # Copyright 2017-2019 Ran Aroussi
#     #
#     # Licensed under the Apache License, Version 2.0 (the "License");
#     # you may not use this file except in compliance with the License.
#     # You may obtain a copy of the License at
#     #
#     #     http://www.apache.org/licenses/LICENSE-2.0
#     #
#     # Unless required by applicable law or agreed to in writing, software
#     # distributed under the License is distributed on an "AS IS" BASIS,
#     # WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#     # See the License for the specific language governing permissions and
#     # limitations under the License.
#     #
#
# PACKAGE CONTENTS
#     base
#     const
#     data
#     exceptions
#     multi
#     scrapers (package)
#     shared
# ...

# %%
IPO2022 = pd.read_csv("IPO_2022.csv")
IPO2022.head()
# Out:
#    IPO Date Symbol                       Company Name IPO Price  Current  \
# 0  5-Jan-22   CITE           Cartica Acquisition Corp   $10.00   $10.67
# 1  6-Jan-22   SCRM  Screaming Eagle Acquisition Corp.   $10.00   $10.32
# 2  7-Jan-22   AMLX       Amylyx Pharmaceuticals, Inc.   $19.00   $23.06
# 3  7-Jan-22   CINC                CinCor Pharma, Inc.   $16.00   $29.06
# 4  7-Jan-22   CXAC         C5 Acquisition Corporation   $10.00   $10.60
#
#    Return
# 0   6.70%
# 1   3.20%
# 2  21.37%
# 3  81.63%
# 4   6.00%

# %%
IPO22_tickers = ""

for t in IPO2022["Symbol"]:
    IPO22_tickers += " " + str(t)
    
IPO22_tickers = IPO22_tickers[1:]
IPO22_tickers
# Out:
# 'CITE SCRM AMLX CINC CXAC VIGL VBOC HOUR BRAC GHIX VCXB ITAQ WAVS HILS TPG WNNR CSLM PPYA ACAB TETE TKLF AIB GAQ BYN DUET KNSW HMA HCMA KYCH LATG FGI CRDO KSCP BWAQ ACAX MTEK MURF ACLX TGR NVCT SSIC ATAK LIVB BYNO EVGR CPAQ SKYX HTCR JGGC SGHL MDV HNRA RACY DRCT TCBP GENQ ASCA FTII AXAC MHUA SMFL PWUP BWV CLIN GSRM FGMC VMCA SPCM SHUA KCAC LBBB PLAO NUBI AKAN GDST RFAC ANTX LCFY RWOD RVSN MSSA XPON DECA GNS EE AFAR STSS YOTA JCSE ACON AIMAU OST TNON CHEA CLRC HLVX BLTE ASCB AUST EDBL BLCO RENE PEPG IVCA GBBK HNVR MCAC ACDC PNAC ASNS PFHC BGXX VEDU OKYO BNRG TOP SVRE PEV ACAC LYT HSCS FLFV GSUN SKGR IE nan ILAG HKD VRAX MAIA MGAM BRSH MOBV PTWO MEGL EMCG HMAC TGL FRZA REBN CHG LUCY GCT STBX MOB JZ PXMD ONFO JFBR HPCO SHPH BIAF EFHT YOSH WLDS CRBG THRD NXL GLST NXU QOMO DMYY LASE AQU SVII TENK HUDA PRME MBLY PLTN SNAL ASPI ATAT ACRV JEWL RAYA LIPO ATMV HSPO COYA ATMC'

# %%
# import IPO 2022 stock data
# Constants

start_date = '2023-01-01'
end_date = '2023-06-01'

IPO22data = yf.download(IPO22_tickers, start_date, end_date)

IPO22data.head()
# Out:
# [*********************100%***********************]  181 of 181 completed
# 5 Failed downloads:
# ['CHG', 'PFHC', 'CINC', 'CPAQ', 'KCAC']: Exception('%ticker%: No timezone found, symbol may be delisted')
#                     Adj Close                                             \
#                          ACAB   ACAC   ACAX       ACDC       ACLX   ACON
# Date
# 2023-01-03 00:00:00     10.20  10.22  10.02  21.400000  31.030001  0.570
# 2023-01-04 00:00:00     10.20  10.24  10.05  21.139999  32.430000  0.507
# 2023-01-05 00:00:00     10.24  10.24  10.04  21.790001  33.509998  0.525
# 2023-01-06 00:00:00     10.24  10.24  10.14  22.379999  33.570000  0.580
# 2023-01-09 00:00:00     10.25  10.24  10.11  22.750000  31.490000  0.500
#
#                                                  ...   Volume                 \
#                       ACRV   AFAR    AIB  AIMAU  ...     VEDU   VIGL    VMCA
# Date                                             ...
# ...

# %%
IPO22data[[('Adj Close',  'ACAB'), ('Close',  'ACAB'), ('High',  'ACAB'), ('Low',  'ACAB'), ('Open',  'ACAB'), ('Volume',  'ACAB')]]
# Out:
#            Adj Close  Close   High     Low    Open  Volume
#                 ACAB   ACAB   ACAB    ACAB    ACAB    ACAB
# Date
# 2023-01-03     10.20  10.20  10.20  10.180  10.180    2300
# 2023-01-04     10.20  10.20  10.20  10.200  10.200       0
# 2023-01-05     10.24  10.24  10.25  10.235  10.235  411700
# 2023-01-06     10.24  10.24  10.24  10.240  10.240     600
# 2023-01-09     10.25  10.25  10.25  10.250  10.250  175000
# ...              ...    ...    ...     ...     ...     ...
# 2023-05-24     10.35  10.35  10.35  10.350  10.350       0
# 2023-05-25     10.35  10.35  10.35  10.350  10.350     200
# 2023-05-26     10.35  10.35  10.35  10.350  10.350       0
# 2023-05-30     10.35  10.35  10.35  10.350  10.350     100
# 2023-05-31     10.35  10.35  10.35  10.350  10.350       0
#
# [103 rows x 6 columns]

# %% [markdown]
# 특히 새로 생긴 기업들은 상장폐지가 된 애들이 있음, 그런애들은 retrieve가 안됌
